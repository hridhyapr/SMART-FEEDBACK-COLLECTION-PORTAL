# %% [markdown]
# <a href="https://colab.research.google.com/github/hridhyapr/SMART-FEEDBACK-COLLECTION-PORTAL/blob/main/Matplotlib_Plotly_ScikitLearn_15_Scenario_Based_Questions_(1)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib, Plotly & Scikit-learn
#
# 15 Scenario-Based Interview Questions

# %% [markdown]
# ## Question 1 (Matplotlib)
#
# **Scenario:** Sales trend line chart not clear. Improve readability.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 2 (Matplotlib)
#
# **Scenario:** Compare revenue across departments using suitable chart.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 3 (Matplotlib)
#
# **Scenario:** Visualize distribution of exam scores.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 4 (Matplotlib)
#
# **Scenario:** Plot multiple product sales on one graph.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 5 (Matplotlib)
#
# **Scenario:** Customize labels, title, legend, and grid.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 6 (Plotly)
#
# **Scenario:** Create an interactive sales dashboard.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 7 (Plotly)
#
# **Scenario:** Display hover details for stock prices.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 8 (Plotly)
#
# **Scenario:** Visualize world sales on a map.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 9 (Plotly)
#
# **Scenario:** Build an interactive scatter plot to find outliers.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 10 (Plotly)
#
# **Scenario:** Create filters/dropdowns for categories.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 11 (Scikit-learn)
#
# **Scenario:** Predict house prices from historical data.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 12 (Scikit-learn)
#
# **Scenario:** Split data into training and testing sets.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 13 (Scikit-learn)
#
# **Scenario:** Handle missing values before model training.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 14 (Scikit-learn)
#
# **Scenario:** Evaluate a classifier using accuracy, precision, recall.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---

# %% [markdown]
# ## Question 15 (Scikit-learn)
#
# **Scenario:** Prevent overfitting in a machine learning model.
#
# **Interview Question:** What approach, library features, and code would you use?
#
# **Your Answer:**
#
# ---
